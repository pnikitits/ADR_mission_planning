# %%
# %load_ext autoreload
# %autoreload 2

from poliastro.plotting import OrbitPlotter3D
from Simulator import Simulator

my_sim = Simulator(starting_index=6 )


my_sim.simulate_action((3 , 20))

frame = OrbitPlotter3D()
frame.plot(my_sim.otv_orbit)
frame.plot(my_sim.debris_list[3].poliastro_orbit)
# Out:
# /Users/pierre/Documents/GitHub/ADR_mission_planning/Simulator/CustomLowLevel.py:49: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 1, 'A', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   r_i = norm(r_i)
# 19.558406149443734 d

# %%
my_sim.simulate_action((5 , 20))

frame = OrbitPlotter3D()
frame.plot(my_sim.otv_orbit)
frame.plot(my_sim.debris_list[5].poliastro_orbit)

# %%
my_sim.simulate_action((8 , 20))

frame = OrbitPlotter3D()
frame.plot(my_sim.otv_orbit)
frame.plot(my_sim.debris_list[8].poliastro_orbit)
