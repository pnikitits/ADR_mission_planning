# %% [markdown]
# # Exhaustive Search : Depth First Strategy

# %%
# Make sure the libraries are reloaded
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
from src.environment.ADR_Environment import ADR_Environment
from src.simulator.Simulator import Simulator
import yaml
import pandas as pd
import csv
from tqdm import tqdm

# %%
with open("src/config/refuel_test_1.yaml") as file: # change file name to use different sweep
        config = yaml.load(file, Loader=yaml.FullLoader)


n_debris = config['environment_parameters']['total_n_debris']

# %%
def generate_permutations(nums, length):
    def backtrack(visited, path):
        if len(path) == length:
            permutations.append(path[:])
            return
        for num in nums:
            if num not in visited:
                visited.add(num)
                path.append(num)
                backtrack(visited, path)
                path.pop()
                visited.remove(num)

    permutations = []
    backtrack(set(), [])
    return permutations

nums_range = range(0, n_debris)  # Range of available integers
combination_length = 5   # Length of the combination
combinations = generate_permutations(nums_range, combination_length)

# %%
sum_rewards_per_combination = []
fuel_used = []
time_used = []

# %%
env = ADR_Environment()
env.env_init(env_info=config['environment_parameters'])
for i, combination in enumerate(tqdm(combinations)):
# rl episode
    # print(f"combination {i}")
    is_terminal = False
    sum_rewards = 0.0
    action_key = combination[0]
    first_debris, _ = env.action_space[action_key]
    # print('days:', _)
    observation = env.env_start(first_debris = first_debris)
    action_id = 0
    num_steps = 0
    for action in combination[1:]:
        (reward, last_state, term) = env.env_step(action)
        sum_rewards += reward
        num_steps += 1
        if term:
            break
    # print(f"Combination: {combination}, Reward: {sum_rewards}")
    sum_rewards_per_combination.append(sum_rewards)
    fuel_used.append(env.dv_max_per_mission - last_state[2])
    time_used.append(env.dt_max_per_mission - last_state[3])

df = pd.DataFrame({'combination': combinations, 'sum_rewards': sum_rewards_per_combination, 'fuel_used': fuel_used, 'time_used': time_used})
# Out:
# first debris:  3
#   1%|          | 4/720 [00:00<00:20, 34.78it/s]
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#   1%|          | 8/720 [00:00<00:24, 29.66it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#   3%|▎         | 19/720 [00:00<00:26, 26.70it/s]
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#   3%|▎         | 22/720 [00:00<00:29, 24.04it/s]
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#   4%|▍         | 31/720 [00:01<00:21, 32.43it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#   6%|▌         | 43/720 [00:01<00:15, 44.38it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#   8%|▊         | 54/720 [00:01<00:15, 42.69it/s]
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#   9%|▉         | 64/720 [00:01<00:16, 39.11it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#  10%|█         | 73/720 [00:02<00:17, 37.88it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#  12%|█▏        | 85/720 [00:02<00:13, 47.09it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#  13%|█▎        | 97/720 [00:02<00:13, 47.48it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#  14%|█▍        | 102/720 [00:02<00:16, 37.17it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#  15%|█▍        | 107/720 [00:02<00:16, 37.02it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#  16%|█▌        | 115/720 [00:03<00:18, 32.95it/s]
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#  17%|█▋        | 123/720 [00:03<00:19, 30.53it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  0
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#  18%|█▊        | 131/720 [00:03<00:17, 33.42it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#  19%|█▉        | 139/720 [00:03<00:17, 34.10it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#  21%|██        | 148/720 [00:04<00:16, 34.64it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#  22%|██▏       | 160/720 [00:04<00:12, 45.76it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#  24%|██▍       | 172/720 [00:04<00:11, 46.73it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#  25%|██▌       | 182/720 [00:04<00:12, 41.42it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#  27%|██▋       | 192/720 [00:05<00:13, 38.80it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#  28%|██▊       | 204/720 [00:05<00:10, 47.94it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#  30%|███       | 216/720 [00:05<00:09, 53.48it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#  31%|███       | 222/720 [00:05<00:12, 40.93it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#  32%|███▏      | 232/720 [00:06<00:13, 34.98it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# converted action:  (5, 30)
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  1
#  33%|███▎      | 240/720 [00:06<00:13, 34.55it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  5
# ...
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#  89%|████████▉ | 641/720 [00:16<00:02, 30.24it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#  90%|█████████ | 650/720 [00:16<00:02, 34.65it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# ADDING FUEL
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#  92%|█████████▏| 662/720 [00:17<00:01, 45.66it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#  94%|█████████▍| 675/720 [00:17<00:00, 48.93it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#  94%|█████████▍| 680/720 [00:17<00:00, 45.27it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  0
# converted action:  (0, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  1
# converted action:  (1, 30)
# max fuel used
# ADDING FUEL
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#  96%|█████████▌| 690/720 [00:17<00:00, 40.71it/s]
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  2
# converted action:  (2, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#  97%|█████████▋| 701/720 [00:18<00:00, 43.54it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  3
# converted action:  (3, 30)
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#  99%|█████████▉| 713/720 [00:18<00:00, 50.80it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
#
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used
#
# ENV START
#
# first debris:  5
# 100%|██████████| 720/720 [00:18<00:00, 39.24it/s]
#  ----- Starting Episode ----
#
#
#  -----  ENV STEP -----
#
# action_key:  4
# converted action:  (4, 30)
# max fuel used

# %%
df = df.sort_values(by='sum_rewards', ascending=False)
df
# Out:
#          combination  sum_rewards  fuel_used  time_used
# 21   [0, 1, 5, 3, 4]          3.0   1.358817  99.239427
# 545  [4, 2, 3, 5, 1]          2.0   1.759329  99.209637
# 217  [1, 5, 0, 2, 4]          2.0   3.403987  99.203085
# 421  [3, 2, 4, 0, 5]          2.0   3.460989  99.116189
# 422  [3, 2, 4, 1, 0]          2.0   2.085092  99.492036
# ..               ...          ...        ...        ...
# 273  [2, 1, 3, 4, 5]          0.0   1.013776  99.025309
# 272  [2, 1, 3, 4, 0]          0.0   1.013776  99.025309
# 271  [2, 1, 3, 0, 5]          0.0   1.013776  99.025309
# 270  [2, 1, 3, 0, 4]          0.0   1.013776  99.025309
# 719  [5, 4, 3, 2, 1]          0.0   1.513097  99.009469
#
# [720 rows x 4 columns]

# %%
df.to_csv('exhaustive_sweep_results.csv', index=False)

# %%
df = df[df['sum_rewards'] == df['sum_rewards'].max()]
df
# Out:
#         combination  sum_rewards  fuel_used  time_used
# 21  [0, 1, 5, 3, 4]          3.0   1.358817  99.239427

# %%
# sort df by fuel used and output the 10 first
df = df.sort_values(by='fuel_used')

# %%
df.head(10)
# Out:
#            combination  sum_rewards  fuel_used  time_used
# 10995  [3, 6, 7, 8, 4]          4.0   1.082799  99.142868
# 23335  [7, 6, 3, 5, 1]          4.0   1.086994  99.225271
# 14733  [4, 8, 7, 6, 3]          4.0   1.087757  99.119550
# 4473   [1, 5, 3, 6, 7]          4.0   1.089940  99.108411
# 23343  [7, 6, 3, 8, 4]          4.0   1.112090  99.142868
# 14602  [4, 8, 3, 6, 7]          4.0   1.114934  99.247235
# 19395  [6, 3, 7, 8, 4]          4.0   1.126924  99.099024
# 14722  [4, 8, 7, 3, 6]          4.0   1.131770  99.119551
# 20311  [6, 7, 3, 5, 1]          4.0   1.152186  99.225271
# 4479   [1, 5, 3, 7, 6]          4.0   1.155220  99.108410
